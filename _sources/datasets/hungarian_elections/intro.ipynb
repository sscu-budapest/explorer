# %% [markdown]
# # Hungarian elections analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (14, 7)

# %%
df_affiliation = pd.read_csv("affiliation.csv")

# %%
df_nominating_organization = pd.read_csv("nominating_organization.csv")

# %%
df_election = pd.read_csv("election.csv")

# %%
df_district_hierarchy = pd.read_csv("district_hierarchy.csv")

# %%
df_geographical_unit = pd.read_csv("geographical_unit.csv")

# %%
df_election_precinct = pd.read_csv("election_precinct.csv")

# %%
df_vote_record = pd.read_csv("vote_record.csv")

# %%
party_level_df = df_vote_record.merge(df_affiliation).merge(df_election_precinct)

# %%
# only first rounds, non individual
relevant_elections = df_election.loc[
    lambda df: ~df["is_individual"] & df["election_id"].str.endswith("1")
]

# %%
# parties that have received over 10% of the votes in 3 different election
parties_for_elections = (
    party_level_df.pivot_table(
        index="party", columns="election_id", values="vote_count", aggfunc="sum"
    )
    .loc[:, relevant_elections["election_id"]]
    .fillna(0)
)

# %%
total_votes_by_election = df_vote_record.merge(df_election_precinct).groupby("election_id")["vote_count"].sum()

# %%
(
    parties_for_elections.loc[
        lambda df: (df / total_votes_by_election[df.columns] > 0.03).sum(axis=1) > 2
    ]
    .rename(columns=relevant_elections.set_index("election_id")["start_date"].to_dict())
    .astype(int)
    .T.style.background_gradient(
        axis=None,
    )
    .set_caption('Number of votes gained by political parties in Hungarian elections')
)
# Out:
# <style type="text/css">
# #T_94709_row0_col0 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_94709_row0_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_94709_row0_col2, #T_94709_row0_col4, #T_94709_row1_col2, #T_94709_row1_col4, #T_94709_row2_col2, #T_94709_row2_col4, #T_94709_row3_col2, #T_94709_row3_col3, #T_94709_row3_col4, #T_94709_row4_col1, #T_94709_row4_col4, #T_94709_row5_col1, #T_94709_row5_col7, #T_94709_row5_col8, #T_94709_row6_col1, #T_94709_row6_col5, #T_94709_row6_col8, #T_94709_row7_col1, #T_94709_row7_col5, #T_94709_row7_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_94709_row0_col3 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_94709_row0_col5 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_94709_row0_col6 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_94709_row0_col7, #T_94709_row2_col7 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_94709_row0_col8 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_94709_row1_col0, #T_94709_row1_col3 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_94709_row1_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_94709_row1_col5 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_94709_row1_col6 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_94709_row1_col7 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_94709_row1_col8 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_94709_row2_col0 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_94709_row2_col1 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_94709_row2_col3 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_94709_row2_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_94709_row2_col6 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_94709_row2_col8, #T_94709_row4_col8 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_94709_row3_col0, #T_94709_row3_col5 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_94709_row3_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_94709_row3_col6 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_94709_row3_col7, #T_94709_row4_col2, #T_94709_row5_col5 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_94709_row3_col8 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_94709_row4_col0, #T_94709_row4_col3 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_94709_row4_col5, #T_94709_row6_col4 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_94709_row4_col6 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_94709_row4_col7, #T_94709_row6_col7 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_94709_row5_col0, #T_94709_row5_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_94709_row5_col2 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_94709_row5_col4 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_94709_row5_col6 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_94709_row6_col0, #T_94709_row6_col3 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_94709_row6_col2 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_94709_row6_col6 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_94709_row7_col0, #T_94709_row7_col3 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_94709_row7_col2 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_94709_row7_col4 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_94709_row7_col6 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_94709_row7_col7 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_94709_">
#   <caption>Number of votes gained by political parties in Hungarian elections</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >party</th>
#       <th class="col_heading level0 col0" >FIDESZ</th>
#       <th class="col_heading level0 col1" >FKGP</th>
#       <th class="col_heading level0 col2" >JOBBIK</th>
#       <th class="col_heading level0 col3" >KDNP</th>
#       <th class="col_heading level0 col4" >LMP</th>
#       <th class="col_heading level0 col5" >MDF</th>
#       <th class="col_heading level0 col6" >MSZP</th>
#       <th class="col_heading level0 col7" >MUNKÁSPÁRT</th>
#       <th class="col_heading level0 col8" >SZDSZ</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >election_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94709_level0_row0" class="row_heading level0 row0" >1990-03-25</th>
#       <td id="T_94709_row0_col0" class="data row0 col0" >439481</td>
#       <td id="T_94709_row0_col1" class="data row0 col1" >576256</td>
#       <td id="T_94709_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_94709_row0_col3" class="data row0 col3" >317183</td>
#       <td id="T_94709_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_94709_row0_col5" class="data row0 col5" >1213825</td>
#       <td id="T_94709_row0_col6" class="data row0 col6" >534898</td>
#       <td id="T_94709_row0_col7" class="data row0 col7" >180899</td>
#       <td id="T_94709_row0_col8" class="data row0 col8" >1050452</td>
#     </tr>
#     <tr>
#       <th id="T_94709_level0_row1" class="row_heading level0 row1" >1994-05-08</th>
#       <td id="T_94709_row1_col0" class="data row1 col0" >379295</td>
#       <td id="T_94709_row1_col1" class="data row1 col1" >476416</td>
#       <td id="T_94709_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_94709_row1_col3" class="data row1 col3" >379573</td>
#       <td id="T_94709_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_94709_row1_col5" class="data row1 col5" >633957</td>
#       <td id="T_94709_row1_col6" class="data row1 col6" >1781867</td>
#       <td id="T_94709_row1_col7" class="data row1 col7" >172117</td>
#       <td id="T_94709_row1_col8" class="data row1 col8" >1066074</td>
#     </tr>
#     <tr>
#       <th id="T_94709_level0_row2" class="row_heading level0 row2" >1998-05-10</th>
#       <td id="T_94709_row2_col0" class="data row2 col0" >1263522</td>
#       <td id="T_94709_row2_col1" class="data row2 col1" >617740</td>
#       <td id="T_94709_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_94709_row2_col3" class="data row2 col3" >116065</td>
#       <td id="T_94709_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_94709_row2_col5" class="data row2 col5" >139934</td>
#       <td id="T_94709_row2_col6" class="data row2 col6" >1445909</td>
#       <td id="T_94709_row2_col7" class="data row2 col7" >183064</td>
#       <td id="T_94709_row2_col8" class="data row2 col8" >353186</td>
#     </tr>
#     <tr>
#       <th id="T_94709_level0_row3" class="row_heading level0 row3" >2002-04-07</th>
#       <td id="T_94709_row3_col0" class="data row3 col0" >2306763</td>
#       <td id="T_94709_row3_col1" class="data row3 col1" >42338</td>
#       <td id="T_94709_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_94709_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_94709_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_94709_row3_col5" class="data row3 col5" >2306763</td>
#       <td id="T_94709_row3_col6" class="data row3 col6" >2361997</td>
#       <td id="T_94709_row3_col7" class="data row3 col7" >121503</td>
#       <td id="T_94709_row3_col8" class="data row3 col8" >313084</td>
#     </tr>
#     <tr>
#       <th id="T_94709_level0_row4" class="row_heading level0 row4" >2006-04-09</th>
#       <td id="T_94709_row4_col0" class="data row4 col0" >2272979</td>
#       <td id="T_94709_row4_col1" class="data row4 col1" >838</td>
#       <td id="T_94709_row4_col2" class="data row4 col2" >119007</td>
#       <td id="T_94709_row4_col3" class="data row4 col3" >2272979</td>
#       <td id="T_94709_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_94709_row4_col5" class="d

# %%
(
    parties_for_elections.pipe(
        lambda df: (df / total_votes_by_election[df.columns])
    ).loc[lambda df: (df > 0.03).sum(axis=1) > 2]
    .rename(columns=relevant_elections.set_index("election_id")["start_date"].to_dict())
    .T.style.background_gradient(
        axis=None,
    )
    .set_caption('Percentage of votes gained by political parties in Hungarian elections')
)
# Out:
# <style type="text/css">
# #T_f2b95_row0_col0 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_f2b95_row0_col1, #T_f2b95_row1_col5 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_f2b95_row0_col2, #T_f2b95_row0_col4, #T_f2b95_row1_col2, #T_f2b95_row1_col4, #T_f2b95_row2_col2, #T_f2b95_row2_col4, #T_f2b95_row3_col2, #T_f2b95_row3_col3, #T_f2b95_row3_col4, #T_f2b95_row4_col1, #T_f2b95_row4_col4, #T_f2b95_row5_col1, #T_f2b95_row5_col7, #T_f2b95_row5_col8, #T_f2b95_row6_col1, #T_f2b95_row6_col5, #T_f2b95_row6_col8, #T_f2b95_row7_col1, #T_f2b95_row7_col5, #T_f2b95_row7_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_f2b95_row0_col3, #T_f2b95_row4_col8 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_f2b95_row0_col5 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_f2b95_row0_col6 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_f2b95_row0_col7 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_f2b95_row0_col8 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_f2b95_row1_col0, #T_f2b95_row1_col3 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_f2b95_row1_col1 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_f2b95_row1_col6 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_f2b95_row1_col7, #T_f2b95_row2_col5 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_f2b95_row1_col8 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_f2b95_row2_col0 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_f2b95_row2_col1 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_f2b95_row2_col3, #T_f2b95_row5_col5 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_f2b95_row2_col6 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_f2b95_row2_col7 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_f2b95_row2_col8 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_f2b95_row3_col0, #T_f2b95_row3_col5 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_f2b95_row3_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_f2b95_row3_col6, #T_f2b95_row4_col0, #T_f2b95_row4_col3 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_f2b95_row3_col7, #T_f2b95_row4_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_f2b95_row3_col8 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_f2b95_row4_col5 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_f2b95_row4_col6 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_f2b95_row4_col7, #T_f2b95_row7_col7 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_f2b95_row5_col0, #T_f2b95_row5_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f2b95_row5_col2 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_f2b95_row5_col4 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_f2b95_row5_col6 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_f2b95_row6_col0, #T_f2b95_row6_col3 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_f2b95_row6_col2 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_f2b95_row6_col4 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_f2b95_row6_col6 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_f2b95_row6_col7 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_f2b95_row7_col0, #T_f2b95_row7_col3 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_f2b95_row7_col2 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_f2b95_row7_col4 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_f2b95_row7_col6 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# </style>
# <table id="T_f2b95_">
#   <caption>Percentage of votes gained by political parties in Hungarian elections</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >party</th>
#       <th class="col_heading level0 col0" >FIDESZ</th>
#       <th class="col_heading level0 col1" >FKGP</th>
#       <th class="col_heading level0 col2" >JOBBIK</th>
#       <th class="col_heading level0 col3" >KDNP</th>
#       <th class="col_heading level0 col4" >LMP</th>
#       <th class="col_heading level0 col5" >MDF</th>
#       <th class="col_heading level0 col6" >MSZP</th>
#       <th class="col_heading level0 col7" >MUNKÁSPÁRT</th>
#       <th class="col_heading level0 col8" >SZDSZ</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >election_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f