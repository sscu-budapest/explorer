# %% [markdown]
# # Hungarian elections analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (14, 7)

# %%
df_affiliation = pd.read_csv("affiliation.csv")

# %%
df_nominating_organization = pd.read_csv("nominating_organization.csv")

# %%
df_election = pd.read_csv("election.csv")

# %%
df_district_hierarchy = pd.read_csv("district_hierarchy.csv")

# %%
df_geographical_unit = pd.read_csv("geographical_unit.csv")

# %%
df_election_precinct = pd.read_csv("election_precinct.csv")

# %%
df_vote_record = pd.read_csv("vote_record.csv")

# %%
party_level_df = df_vote_record.merge(df_affiliation).merge(df_election_precinct)

# %%
# only first rounds, non individual
relevant_elections = df_election.loc[
    lambda df: ~df["is_individual"] & df["election_id"].str.endswith("1")
]

# %%
# parties that have received over 10% of the votes in 3 different election
parties_for_elections = (
    party_level_df.pivot_table(
        index="party", columns="election_id", values="vote_count", aggfunc="sum"
    )
    .loc[:, relevant_elections["election_id"]]
    .fillna(0)
)

# %%
total_votes_by_election = df_vote_record.merge(df_election_precinct).groupby("election_id")["vote_count"].sum()

# %%
(
    parties_for_elections.loc[
        lambda df: (df / total_votes_by_election[df.columns] > 0.03).sum(axis=1) > 2
    ]
    .rename(columns=relevant_elections.set_index("election_id")["start_date"].to_dict())
    .astype(int)
    .T.style.background_gradient(
        axis=None,
    )
    .set_caption('Number of votes gained by political parties in Hungarian elections')
)
# Out:
# <style type="text/css">
# #T_655d3_row0_col0, #T_655d3_row7_col9, #T_655d3_row8_col4 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_655d3_row0_col1, #T_655d3_row0_col4 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_655d3_row0_col2, #T_655d3_row0_col6, #T_655d3_row0_col9, #T_655d3_row1_col0, #T_655d3_row1_col2, #T_655d3_row1_col8, #T_655d3_row1_col9, #T_655d3_row2_col0, #T_655d3_row2_col2, #T_655d3_row2_col5, #T_655d3_row2_col8, #T_655d3_row3_col0, #T_655d3_row3_col3, #T_655d3_row3_col5, #T_655d3_row3_col8, #T_655d3_row4_col2, #T_655d3_row4_col6, #T_655d3_row4_col9, #T_655d3_row5_col0, #T_655d3_row5_col3, #T_655d3_row5_col5, #T_655d3_row5_col8, #T_655d3_row6_col2, #T_655d3_row6_col6, #T_655d3_row6_col9, #T_655d3_row7_col0, #T_655d3_row7_col3, #T_655d3_row7_col4, #T_655d3_row7_col5, #T_655d3_row7_col8, #T_655d3_row8_col0, #T_655d3_row8_col3, #T_655d3_row8_col5, #T_655d3_row8_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_655d3_row0_col3 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_655d3_row0_col5 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_655d3_row0_col7, #T_655d3_row0_col8 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_655d3_row1_col1, #T_655d3_row1_col4 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_655d3_row1_col3 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_655d3_row1_col5, #T_655d3_row5_col1, #T_655d3_row5_col4 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_655d3_row1_col6, #T_655d3_row3_col6 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_655d3_row1_col7 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_655d3_row2_col1, #T_655d3_row2_col4 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_655d3_row2_col3, #T_655d3_row3_col4 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_655d3_row2_col6, #T_655d3_row4_col5 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_655d3_row2_col7 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_655d3_row2_col9 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_655d3_row3_col1 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_655d3_row3_col2 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_655d3_row3_col7 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_655d3_row3_col9 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_655d3_row4_col0, #T_655d3_row4_col7, #T_655d3_row4_col8 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_655d3_row4_col1, #T_655d3_row4_col4 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_655d3_row4_col3 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_655d3_row5_col2 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_655d3_row5_col6 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_655d3_row5_col7 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_655d3_row5_col9 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_655d3_row6_col0, #T_655d3_row6_col3, #T_655d3_row6_col5, #T_655d3_row6_col7, #T_655d3_row6_col8 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_655d3_row6_col1, #T_655d3_row6_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_655d3_row7_col1, #T_655d3_row7_col6 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_655d3_row7_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_655d3_row7_col7 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_655d3_row8_col1 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_655d3_row8_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_655d3_row8_col6 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_655d3_row8_col7 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_655d3_row8_col9 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# </style>
# <table id="T_655d3">
#   <caption>Number of votes gained by political parties in Hungarian elections</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >party</th>
#       <th id="T_655d3_level0_col0" class="col_heading level0 col0" >DK</th>
#       <th id="T_655d3_level0_col1" class="col_heading level0 col1" >FIDESZ</th>
#       <th id="T_655d3_level0_col2" class="col_heading level0 col2" >FKGP</th>
#       <th id="T_655d3_level0_col3" class="col_heading level0 col3" >JOBBIK</th>
#       <th id="T_655d3_level0_col4" class="col_heading level0 col4" >KDNP</th>
#       <th id="T_655d3_level0_col5" class="col_heading level0 col5" >LMP</th>
#       <th id="T_655d3_level0_col6" class="col_heading level0 col6" >MDF</th>
#       <th id="T_655d3_level0_col7" class="col_heading level0 col7" >MSZP</th>
#       <th id="T_655d3_level0_col8" class="col_heading level0 col8" >PM</th>
#       <th id="T_655d3_level0_col9" class="col_heading level0 col9" >SZDSZ</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >election_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_655d3_level0_row0" class="row_heading level0 row0" >2018-04-08</th>
#       <td id="T_655d3_row0_col0" class="data row0 col0" >306853</td>
#       <td id="T_655d3_row0_col1" class="data row0 col1" >2607899</td>
#       <td id="T_655d3_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_655d3_row0_col3" class="data row0 col3" >1090331</td>
#       <td id="T_655d3_row0_col4" class="data row0 col4" >2607899</td>
#       <td id="T_655d3_row0_col5" class="data row0 col5" >399507</td>
#       <td id="T_655d3_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_655d3_row0_col7" class="data row0 col7" >680680</td>
#       <td id="T_655d3_row0_col8" class="data row0 col8" >680680</td>
#       <td id="T_655d3_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_655d3_level0_row1" class="row_heading level0 row1" >2010-04-11</th>
#       <td id="T_655d3_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_655d3_row1_col1" class="data row1 col1" >2706282</td>
#       <td id="T_655d3_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_655d3_row1_col3" class="data row1 col3" >855263</td>
#       <td id="T_655d3_row1_col4" class="data row1 col4" >2706282</td>
#       <td id="T_655d3_row1_col5" class="data row1 col5" >383173</td>
#       <td id="T_655d3_row1_col6" class="data row1 col6" >135357</td>
#       <td id="T_655d3_row1_col7" class="data row1 col7" >990253</td>
#       <td id="T_655d3_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_655d3_row1_col9" class="data row1 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_655d3_level0_row2" class="row_heading level0 row2" >2006-04-09</th>
#       <td id="T_655d3_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_655d3_row2_col1" class="data row2 col1" >2272962</td>
#       <td id="T_655d3_row2_col2" class="data row2 col2" >822</td>
#       <td id="T_655d3_row2_col3" class="data row2 col3" >116463</td>
#       <td id="T_655d3_row2_col4" class="data row2 col4" >2272962</td>
#       <td id="T_655d3_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_655d3_row2_col6" class="data row2 col6" >271881</td>
#       <td id="T_655d3_row2_col7" class="data row2 col7" >2336684</td>
#       <td id="T_655d3_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_655d3_row2_col9" class="data row2 col9" >350196</td>
#     </tr>
#     <tr>
#       <th id="T_655d3_level0_row3" class="row_heading level0 row3" >1998-05-10</th>
#       <td id="T_655d3_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_655d3_row3_col1" class="data row3 col1" >1263504</td>
#       <td id="T_655d3_row3_col2" class="data row3 col2" >617713</td>
#       <td id="T_655d3_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_655d3_row3_col4" class="data row3 col4" >113710</td>
#       <td id="T_655d3_row3_col5" class="data row3 col5" >0</td>
#       <td i

# %%
(
    parties_for_elections.pipe(
        lambda df: (df / total_votes_by_election[df.columns])
    ).loc[lambda df: (df > 0.03).sum(axis=1) > 2]
    .rename(columns=relevant_elections.set_index("election_id")["start_date"].to_dict())
    .T.style.background_gradient(
        axis=None,
    )
    .set_caption('Percentage of votes gained by political parties in Hungarian elections')
)
# Out:
# <style type="text/css">
# #T_09f5f_row0_col0 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_09f5f_row0_col1, #T_09f5f_row0_col4 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_09f5f_row0_col2, #T_09f5f_row0_col6, #T_09f5f_row0_col9, #T_09f5f_row1_col0, #T_09f5f_row1_col2, #T_09f5f_row1_col8, #T_09f5f_row1_col9, #T_09f5f_row2_col0, #T_09f5f_row2_col2, #T_09f5f_row2_col5, #T_09f5f_row2_col8, #T_09f5f_row3_col0, #T_09f5f_row3_col3, #T_09f5f_row3_col5, #T_09f5f_row3_col8, #T_09f5f_row4_col2, #T_09f5f_row4_col6, #T_09f5f_row4_col9, #T_09f5f_row5_col0, #T_09f5f_row5_col3, #T_09f5f_row5_col5, #T_09f5f_row5_col8, #T_09f5f_row6_col2, #T_09f5f_row6_col6, #T_09f5f_row6_col9, #T_09f5f_row7_col0, #T_09f5f_row7_col3, #T_09f5f_row7_col4, #T_09f5f_row7_col5, #T_09f5f_row7_col8, #T_09f5f_row8_col0, #T_09f5f_row8_col3, #T_09f5f_row8_col5, #T_09f5f_row8_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_09f5f_row0_col3, #T_09f5f_row5_col9 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_09f5f_row0_col5 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_09f5f_row0_col7, #T_09f5f_row0_col8 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_09f5f_row1_col1, #T_09f5f_row1_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_09f5f_row1_col3 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_09f5f_row1_col5 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_09f5f_row1_col6, #T_09f5f_row3_col4 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_09f5f_row1_col7 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_09f5f_row2_col1, #T_09f5f_row2_col4, #T_09f5f_row7_col7 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_09f5f_row2_col3 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_09f5f_row2_col6 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_09f5f_row2_col7 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_09f5f_row2_col9, #T_09f5f_row8_col4 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_09f5f_row3_col1 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_09f5f_row3_col2 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_09f5f_row3_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_09f5f_row3_col7 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_09f5f_row3_col9 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_09f5f_row4_col0, #T_09f5f_row4_col7, #T_09f5f_row4_col8 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_09f5f_row4_col1, #T_09f5f_row4_col4 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_09f5f_row4_col3 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_09f5f_row4_col5, #T_09f5f_row7_col9 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_09f5f_row5_col1, #T_09f5f_row5_col4 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_09f5f_row5_col2 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_09f5f_row5_col6, #T_09f5f_row8_col2 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_09f5f_row5_col7 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_09f5f_row6_col0, #T_09f5f_row6_col3, #T_09f5f_row6_col5, #T_09f5f_row6_col7, #T_09f5f_row6_col8 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_09f5f_row6_col1, #T_09f5f_row6_col4 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_09f5f_row7_col1, #T_09f5f_row7_col6 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_09f5f_row7_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_09f5f_row8_col1 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_09f5f_row8_col6 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_09f5f_row8_col7 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_09f5f_row8_col9 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# </style>
# <table id="T_09f5f">
#   <caption>Percentage of votes gained by political parties in Hungarian elections</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >party</th>
#       <th id="T_09f5f_level0_col0" class="col_heading level0 col0" >DK</th>
#       <th id="T_09f5f_level0_col1" class="col_heading level0 col1" >FIDESZ</th>
#       <th id="T_09f5f_level0_col2" class="col_heading level0 col2" >FKGP</th>
#       <th id="T_09f5f_level0_col3" class="col_heading level0 col3" >JOBBIK</th>
#       <th id="T_09f5f_level0_col4" class="col_heading level0 col4" >KDNP</th>
#       <th id="T_09f5f_level0_col5" class="col_heading level0 col5" >LMP</th>
#       <th id="T_09f5f_level0_col6" class="col_heading level0 col6" >MDF</th>
#       <th id="T_09f5f_level0_col7" class="col_heading level0 col7" >MSZP</th>
#       <th id="T_09f5f_level0_col8" class="col_heading level0 col8" >PM</th>
#       <th id="T_09f5f_level0_col9" class="col_heading level0 col9" >SZDSZ</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >election_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09f5f_level0_row0" class="row_heading level0 row0" >2018-04-08</th>
#       <td id="T_09f5f_row0_col0" class="data row0 col0" >0.056236</td>
#       <td id="T_09f5f_row0_col1" class="data row0 col1" >0.477945</td>
#       <td id="T_09f5f_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_09f5f_row0_col3" class="data row0 col3" >0.199823</td>
#       <td id="T_09f5f_row0_col4" class="data row0 col4" >0.477945</td>
#       <td id="T_09f5f_row0_col5" class="data row0 col5" >0.073217</td>
#       <td id="T_09f5f_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_09f5f_row0_col7" class="data row0 col7" >0.124747</td>
#       <td id="T_09f5f_row0_col8" class="data row0 col8" >0.124747</td>
#       <td id="T_09f5f_row0_col9" class="data row0 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09f5f_level0_row1" class="row_heading level0 row1" >2010-04-11</th>
#       <td id="T_09f5f_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_09f5f_row1_col1" class="data row1 col1" >0.527795</td>
#       <td id="T_09f5f_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_09f5f_row1_col3" class="data row1 col3" >0.166798</td>
#       <td id="T_09f5f_row1_col4" class="data row1 col4" >0.527795</td>
#       <td id="T_09f5f_row1_col5" class="data row1 col5" >0.074729</td>
#       <td id="T_09f5f_row1_col6" class="data row1 col6" >0.026398</td>
#       <td id="T_09f5f_row1_col7" class="data row1 col7" >0.193125</td>
#       <td id="T_09f5f_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_09f5f_row1_col9" class="data row1 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09f5f_level0_row2" class="row_heading level0 row2" >2006-04-09</th>
#       <td id="T_09f5f_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_09f5f_row2_col1" class="data row2 col1" >0.421047</td>
#       <td id="T_09f5f_row2_col2" class="data row2 col2" >0.000152</td>
#       <td id="T_09f5f_row2_col3" class="data row2 col3" >0.021574</td>
#       <td id="T_09f5f_row2_col4" class="data row2 col4" >0.421047</td>
#       <td id="T_09f5f_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_09f5f_row2_col6" class="data row2 col6" >0.050364</td>
#       <td id="T_09f5f_row2_col7" class="data row2 col7" >0.432851</td>
#       <td id="T_09f5f_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_09f5f_row2_col9" class="data row2 col9" >0.064871</td>
#     </tr>
#     <tr>
#       <th id="T_09f5f_level0_row3" class="row_heading level0 row3" >1998-05-10</th>
#       <td id="T_09f5f_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_09f5f_row3_col1" class="data row3 col1" >0.282987</td>
#       <td id="T_09f5f_row3_col2" class="data row3 col2" >0.138349</td>
#       <td id="T_09f5f_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_09
